# %%
import pandas as pd

# Especifica la ruta al archivo en Google Drive
file_path = '/content/drive/MyDrive/netflix_revenue_updated-ENTREGA-4.csv'

# Carga el archivo CSV
df = pd.read_csv(file_path)

# Muestra las primeras filas del DataFrame
df.head()
# Out:
#          Date  Ganancias de streaming global  \
# 0  31-03-2019                     4520992000
# 1  30-06-2019                     4923116000
# 2  30-09-2019                     5244905000
# 3  31-12-2019                     5467434000
# 4  31-03-2020                     5767691000
#
#    Ganancias de streaming EEUU & Canadá  \
# 0                            2256851000
# 1                            2501199000
# 2                            2621250000
# 3                            2671908000
# 4                            2702776000
#
#    Ganancias de streaming Europa, MO y África   Ganancias de streaming LATAM  \
# 0                                   1233379000                     630472000
# 1                                   1319087000                     677136000
# 2                                   1428040000                     741434000
# 3                                   1562561000                     746392000
# ...
